# %% [markdown]
# ### Creating & Running code cells, arrow-up, and arrow-down

# %%
a = 1

# %%
b = 2

# %%
print(a+b)
# Out:
# 3

# %% [markdown]
# ### Deleting a code cell

# %%
c = 3
print(c)
# Out:
# 3

# %%
print(c-b)
# Out:
# 1

# %%
a=100
print(a+b)
# Out:
# 102

# %% [markdown]
# ### A variable can begin with any alphabets or an underscore.

# %% [markdown]
# ### Avoid preassigned keywords

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']
