# %%
# 1. mate character Period .: 한개의 임의의 문자

import re

text= "cat, hat, bat, sat, mat, comat, unbated"
pattern= r".at"  # text 중 pattern의 'at'으로 끝나는 세글자 단어를 찾음

# re.findall(): 'at'으로 끝나는 세글자 단어를 찾아 리스트로 반환
matches= re.findall(pattern, text)

for match in matches:
  print("Match:", match)
# Out:
# Match: cat
# Match: hat
# Match: bat
# Match: sat
# Match: mat
# Match: mat
# Match: bat

# %%
# 1a
text2= "at, cat, at, hat, bat, sat, mat, combat, unbated"

matches= re.findall(pattern, text2)  # 1과 동일한 패턴 사용

for i in matches:
  print("match:", i)
# Out:
# match: cat
# match:  at
# match: hat
# match: bat
# match: sat
# match: mat
# match: bat
# match: bat

# %%
# 2. meta character Question mark ?: ? 앞의 문자가 0번 혹은 1번 나타날 수 있음

import re

text= "color or colour?"
pattern= r"colou?r"  # u는 0번 또는 1번 나타날 수 있음

matches= re.findall(pattern, text)

for i in matches:
  print("Match:", i)
# Out:
# Match: color
# Match: colour

# %%
# 2a
text2= "color, colour, or coloer?"
pattern= r"colou?r"

matches= re.findall(pattern, text2)

for i in matches:
  print("Match:", i)
# Out:
# Match: color
# Match: colour

# %%
# 3. meta character Asterisk *: 앞의 요소가 0회 이상 나타날 수 있음

import re

text= "ab, ac, abc, abbc, aabbc, abbbbbbbbbbbbbbc"
pattern = r"ab*c"   # b가 0회 이상 반복 가능

matches = re.findall(pattern, text)

for i in matches:
    print("Match:", i)
# Out:
# Match: ac
# Match: abc
# Match: abbc
# Match: abbc
# Match: abbbbbbbbbbbbbbc

# %%
# 4. meta character $: 문자열의 끝을 나타내는 메타 문자

import re

text= "Python is a popular programming language. Python is versatile."
pattern= r'versatile.$'   # 'versatile'이 끝에 오는 경우를 찾음

matches= re.findall(pattern, text)

for i in matches:
  print("Match:", i)
# Out:
# Match: versatile.

# %%
# 4a

import re

text= "Python is a popular programming language. Python is versatile."
pattern= r'tile.$'

matches= re.findall(pattern, text)

for i in matches:
  print("Match:", i)
# Out:
# Match: tile.

# %%
# 4b

import re

text= "Python is a popular programming language. Python is versatile."
pattern= r'language.$'

matches= re.findall(pattern, text)

# 'language.'는 문자열의 끝이 아니므로 출력값이 안나옴
for i in matches:
  print("Match:", i)

# %%
# 5. meta character ^: 패턴의 시작 부분을 나타냄

import re

text = "Python is a programming language. Python is versatile. We all love Python."
pattern = r'^Python'   # Python으로 시작하는 경우를 찾음

matches= re.findall(pattern, text)

for i in matches:
  print("Match:", i)
# Out:
# Match: Python

# %%
# 5a

import re

text = "Python is a programming language. Python is versatile. We all love Python."
pattern = r'^is'

matches = re.findall(pattern, text)

# 'is'는 문자열이 시작하는 경우가 아니므로 출력값이 안나옴
for i in matches:
    print("Match:", i)

# %%
# 6. meta character +: 앞의 요소가 1회 이상 나타나야 함을 나타냄

import re

text = "cat, caat, caaat, sat, set"
pattern = r"ca+t"  # c 다음 문자 a가 1회 이상 반복되어야 함

matches = re.findall(pattern, text)

for i in matches:
    print("Match:", i)
# Out:
# Match: cat
# Match: caat
# Match: caaat

# %%
# 6a

import re

text = "cat, caat, caaat, sat, set"
pattern = r"a+t"  # a가 1회 이상 반복되어야 함

matches = re.findall(pattern, text)

for i in matches:
    print("Match:", i)
# Out:
# Match: at
# Match: aat
# Match: aaat
# Match: at

# %%
# 7.

import re

text = "123 4567 89 12345"
pattern = r"\d{3}"   # '\d: 숫자를 나타냄, {3}: 3개의 연속된 숫자를 찾음

matches = re.findall(pattern, text)

for i in matches:
    print("Match:", i)
# Out:
# Match: 123
# Match: 456
# Match: 123

# %%
# 8.

import re

text = "The numbers are 12345678999, 12345, 987, and 56789."
pattern = r"\d{3,5}"   # 3자리에서 5자리까지의 연속된 숫자를 찾음

matches = re.findall(pattern, text)

for i in matches:
    print("Match:", i)
# Out:
# Match: 12345
# Match: 67899
# Match: 12345
# Match: 987
# Match: 56789

# %%
# 9.

import re

text = "The word 'hello' is repeated many times: hello hello hello hello hello"
pattern= r"(hello ){2,}"   # hello가 최소 2번 이상 반복된 경우를 찾음
# 여기서는 hellohellohellohellohello라는 패턴이 1 번 있어서 hello가 출력됨

matches = re.findall(pattern, text)

for i in matches:
    print("Match:", i)
# Out:
# Match: hello

# %%
# 9a

import re

text = "The word 'hello' is repeated many times: hellohellohellohellohello hellohellohellohellohello hellohellohellohellohello"
pattern = r"(hello){2,}"
# 여기서는 hellohellohellohellohello라는 패턴이 3 번 있어서 hello가 3회 출력됨

matches = re.findall(pattern, text)

for i in matches:
    print("Match:", i)
# Out:
# Match: hello
# Match: hello
# Match: hello

# %%
# 10. \d: 대괄호 안의 문자들 중 한개의 숫자와 일치

import re

text= "The price is $100."
pattern= r"[\d]"   # 숫자를 찾음

matches= re.findall(pattern, text)

for i in matches:
  print("Match:", i)
# Out:
# Match: 1
# Match: 0
# Match: 0

# %%
# 10a

import re

text = "The price is $100."
pattern = r"[e\d]"   # e와 숫자를 찾음

matches = re.findall(pattern, text)

for i in matches:
    print("Match:", i)
# Out:
# Match: e
# Match: e
# Match: 1
# Match: 0
# Match: 0

# %%
# 11. [amk]: 대괄호 안의 문자들 중 한개의 문자와 매치

import re

text= "I have an apple and a monkey in the kitchen."
pattern= r"[amk]"   # a, m, k 중 하나의 문자를 찾음

matches= re.findall(pattern, text)

for i in matches:
  print("Match:", i)
# Out:
# Match: a
# Match: a
# Match: a
# Match: a
# Match: a
# Match: m
# Match: k
# Match: k

# %%
# 12. [a-z]: a부터 z까지의 모든 소문자 글자와 일치

import re

text= "The quick brown fox jumps over the lazy dog."
pattern= r"[a-z]"   # 소문자 알파벳에 일치하는 경우 찾음

matches= re.findall(pattern, text)

for i in matches:
  print("Match:", i)
# Out:
# Match: h
# Match: e
# Match: q
# Match: u
# Match: i
# Match: c
# Match: k
# Match: b
# Match: r
# Match: o
# Match: w
# Match: n
# Match: f
# Match: o
# Match: x
# Match: j
# Match: u
# Match: m
# Match: p
# Match: s
# Match: o
# Match: v
# Match: e
# Match: r
# Match: t
# Match: h
# Match: e
# Match: l
# Match: a
# Match: z
# Match: y
# Match: d
# Match: o
# Match: g

# %%
# 13. [A-Z]: a부터 z까지의 모든 대문자 글자와 일치

import re

text= "\"The book titles are 'The Aesop for Children', 'Harry Potter', and 'Pride and Prejudice',\" said Amelia."
pattern= r"[A-Z]"   # 대문자 알파벳에 일치하는 경우 찾음

matches= re.findall(pattern, text)

for i in matches:
  print("Match:", i)
# Out:
# Match: T
# Match: T
# Match: A
# Match: C
# Match: H
# Match: P
# Match: P
# Match: P
# Match: A

# %%
# 14. [a-zA-Z]: 알파벳 대소문자 구분없이 모든 문자와 일치

import re

text= "New York is a wonderful city."
pattern= r"[a-zA-Z]"

matches= re.findall(pattern, text)

for i in matches:
  print("Match:", i)
# Out:
# Match: N
# Match: e
# Match: w
# Match: Y
# Match: o
# Match: r
# Match: k
# Match: i
# Match: s
# Match: a
# Match: w
# Match: o
# Match: n
# Match: d
# Match: e
# Match: r
# Match: f
# Match: u
# Match: l
# Match: c
# Match: i
# Match: t
# Match: y

# %%
# 15. [0-9]: 모든 정수와 일치

import re

text= "A total of 149 episodes of The Aesop for Children."
pattern= r"[0-9]"   # 숫자를 찾을 때 사용

matches= re.findall(pattern, text)

for i in matches:
  print("Match:", i)
# Out:
# Match: 1
# Match: 4
# Match: 9

# %%
# 15a

import re

text = "In mathematics, 3.14 is a decimal approximation of the mathematical constant π (pi)."
pattern = r"[0-9]"

matches= re.findall(pattern, text)

for i in matches:
  print("Match:", i)
# Out:
# Match: 3
# Match: 1
# Match: 4

# %%
# 16. [a-zA-Z0-9]: 대소문자 구분없이 알파벳과 숫자를 포함하는 모든 문자와 일치

import re

text= "24 Hours a Day, 7 Days a Week, & 365 Days a Year!"
pattern= r"[a-zA-Z0-9]"

matches= re.findall(pattern, text)

for i in matches:
  print("Match:", i)
# Out:
# Match: 2
# Match: 4
# Match: H
# Match: o
# Match: u
# Match: r
# Match: s
# Match: a
# Match: D
# Match: a
# Match: y
# Match: 7
# Match: D
# Match: a
# Match: y
# Match: s
# Match: a
# Match: W
# Match: e
# Match: e
# Match: k
# Match: 3
# Match: 6
# Match: 5
# Match: D
# Match: a
# Match: y
# Match: s
# Match: a
# Match: Y
# Match: e
# Match: a
# Match: r

# %%
# 17. [^a-zA-Z0-9]: 대소문자 및 숫자를 제외한 모든 문자와 일치
import re

text= "24 Hours a Day,\n7 Days a Week,\n $ \t 365 Days a Year!"
pattern= r"[^a-zA-Z0-9]"

matches= re.findall(pattern, text)

for i in matches:
  print("Match:", i)
# Out:
# Match:
# Match:
# Match:
# Match: ,
# Match:
#
# Match:
# Match:
# Match:
# Match: ,
# Match:
#
# Match:
# Match: $
# Match:
# Match:
# Match:
# Match:
# Match:
# Match:
# Match: !

# %%
# 19. |: or과 일치

import re

text= "The color can be either red, green, or blue."
pattern= r"(red|blue)"   # red 또는 blue에 일치하는 경우 찾음

matches= re.findall(pattern, text)

for i in matches:
  print("Match:", i)
# Out:
# Match: red
# Match: blue

# %%
from io import TextIOBase
# 20.

import re

text = "It cost me $715.45 and more."

## pattern1
pattern1 = r"more.$"   # more이 끝에 오는 경우를 찾음

matches1 = re.findall(pattern1, text)

for i in matches1:
  print("Match1:", i)

## pattern2
pattern2 = r"\$*7"

matches2 = re.findall(pattern2, text)

for i in matches2:
  print("Match2", i)
# Out:
# Match1: more.
# Match2 $7

# %%
# 21. \: 특수문자 매칭

import re

text= "Hello, world.\n This is test #5."
pattern= r"\."   # .인 경우를 찾음

matches= re.findall(pattern, text)

for i in matches:
  print("Match:", i)
# Out:
# Match: .
# Match: .

# %%
# 21a

import re

text= "Hello, world.\n This is test #5."
pattern= r"."  # .은 어떤 문자든 하나인 경우를 찾음

matches= re.findall(pattern, text)

for i in matches:
  print("Match:", i)
# Out:
# Match: H
# Match: e
# Match: l
# Match: l
# Match: o
# Match: ,
# Match:
# Match: w
# Match: o
# Match: r
# Match: l
# Match: d
# Match: .
# Match:
# Match: T
# Match: h
# Match: i
# Match: s
# Match:
# Match: i
# Match: s
# Match:
# Match: t
# Match: e
# Match: s
# Match: t
# Match:
# Match: #
# Match: 5
# Match: .

# %%
# 22. \를 사용하여 특수문자 매칭

import re

text= "The price is $100."
pattern= r"\$"   # \를 사용하여 $ 매칭

matches= re.findall(pattern, text)

for i in matches:
  print("Match:", i)
# Out:
# Match: $

# %%
# 23. \d 예시

import re

text= "The price is $100."
pattern= r"\d"   # 각각의 숫자에 일치

matches= re.findall(pattern, text)

for i in matches:
  print("Match:", i)
# Out:
# Match: 1
# Match: 0
# Match: 0

# %%
# 23a.
# 100이라는 문자열 전체에 대한 하나의 일치를 원할 경우

import re

text= "The price is $100."
pattern= r"\d+"   # 각각의 숫자가 연속해서 일치하도록 패턴 지정

matches= re.findall(pattern, text)

for i in matches:
  print("Match:", i)
# Out:
# Match: 100

# %%
# 24. \D 예시

import re

text= "The price is $100."
pattern= r"\D"   # 숫자가 아닌 문자, 기호에 일치

matches= re.findall(pattern, text)

for i in matches:
  print("Match:", i)
# Out:
# Match: T
# Match: h
# Match: e
# Match:
# Match: p
# Match: r
# Match: i
# Match: c
# Match: e
# Match:
# Match: i
# Match: s
# Match:
# Match: $
# Match: .

# %%
# 25. \s 예시

import re

text= "Hello   World"
pattern= r"\s"   # 공백문자에 일치

matches= re.findall(pattern, text)

for match in matches:
  print("Match:", match)
# Out:
# Match:
# Match:
# Match:

# %%
# 26. \S 예시

import re

text= "Hello   World"
pattern= r"\S"   # 공백문자가 아닌 문자에 일치

matches= re.findall(pattern, text)

for match in matches:
  print("Match:", match)
# Out:
# Match: H
# Match: e
# Match: l
# Match: l
# Match: o
# Match: W
# Match: o
# Match: r
# Match: l
# Match: d

# %%
# 27. \w 예시

import re

text= "Python is _awesome_!"
pattern= r"\w"   # 문자 또는 숫자에 일치

matches= re.findall(pattern, text)

for match in matches:
  print("Match:", match)
# Out:
# Match: P
# Match: y
# Match: t
# Match: h
# Match: o
# Match: n
# Match: i
# Match: s
# Match: _
# Match: a
# Match: w
# Match: e
# Match: s
# Match: o
# Match: m
# Match: e
# Match: _

# %%
# 28. \w+

import re

text= "Python is awesome!"
pattern= r"\w+"   # 대소문자, 숫자, 밑줄 포함 하나 이상의 연속된 경우를 찾음

matches= re.findall(pattern, text)

for match in matches:
   print("Match:", match)
# Out:
# Match: Python
# Match: is
# Match: awesome

# %%
# 29. \를 사용하여 특수한 문자 클래스 생성 가능

import re

text= "123 Main Street and 5 Avenue "
pattern= r"\d\s\w+"   # 하나의 숫자, 하나의 공백, 하나 이상의 단어 매칭

matches= re.findall(pattern, text)

for i in matches:
  print("Match:", i)
# Out:
# Match: 3 Main
# Match: 5 Avenue

# %% [markdown]
# - 모든 자리 숫자가 다 나오게 re 변경해보기

# %%
# 29a

import re

text = "123 Main Street and 5 Avenue "
pattern = r"\d+\s\w"  # 모든 1개 이상의 숫자, 공백, 단어 매칭

matches = re.findall(pattern, text)

for i in matches:
    print("Match:", i)

#add a regular print() function
print("Match:", matches)
# Out:
# Match: 123 M
# Match: 5 A
# Match: ['123 M', '5 A']

# %%
# 29b

import re

text = "123 _Main_ Street_ and 5th Avenue "
pattern = r"\d+\s\w+"

matches = re.findall(pattern, text)

for i in matches:
  print("Match:", i)
# Out:
# Match: 123 _Main_

# %%
# 14. [0-9] (뜻: 모든 숫자 (정수 형태)와 일치)일치

import re

text = "A total of 149 episodes of The Aesop for Children."
pattern= r"[0-9]"  # 숫자 찾을 때 사용

matches = re.findall(pattern, text)

for i in matches:
  print("Match:", i)
# Out:
# Match: 1
# Match: 4
# Match: 9

# %%
# 14. [0-9] (뜻: 모든 숫자 (정수 형태)와 일치)일치

import re

text = "A total of 149 episodes of The Aesop for Children."
#pattern= r"[0-9]"  # 숫자 찾을 때 사용
pattern= r"[0123456789]"

matches = re.findall(pattern, text)

for i in matches:
  print("Match:", i)
# Out:
# Match: 1
# Match: 4
# Match: 9

# %%
# 14. [0-9] (뜻: 모든 숫자 (정수 형태)와 일치)일치

import re

text = "A total of 149 episodes of The Aesop for Children."
#pattern= r"[0-9]"  # 숫자 찾을 때 사용
#pattern= r"[0123456789]"
pattern= r"[a-zA-Z0-9]"  # 알파벳(대소문자 구분없이)과 숫자를 포함하는 모든 문자를 찾을 때 사용, 기호는 포함안됨

matches = re.findall(pattern, text)

for i in matches:
  print("Match:", i)
# Out:
# Match: A
# Match: t
# Match: o
# Match: t
# Match: a
# Match: l
# Match: o
# Match: f
# Match: 1
# Match: 4
# Match: 9
# Match: e
# Match: p
# Match: i
# Match: s
# Match: o
# Match: d
# Match: e
# Match: s
# Match: o
# Match: f
# Match: T
# Match: h
# Match: e
# Match: A
# Match: e
# Match: s
# Match: o
# Match: p
# Match: f
# Match: o
# Match: r
# Match: C
# Match: h
# Match: i
# Match: l
# Match: d
# Match: r
# Match: e
# Match: n

# %%
# 17 | (뜻: or과 일치)

import re

text= "The color can be either red, green, or blue."
pattern= r"(red|blue)"  # "either red" 또는 "blue"에 일치하는 패턴
matches= re.findall(pattern, text)

for i in matches:
  print("Match:", i)
# Out:
# Match: red
# Match: blue

# %%
# 17 | (뜻: or과 일치)

import re

text= "The color can be either red, green, or purple."
pattern= r"(red|blue)"

matches= re.findall(pattern, text)

for i in matches:
  print("Match:", i)
# Out:
# Match: red

# %%
# 18
from io import TextIOBase
import re

text= "It cost me \$715.45 and more."

pattern1= r"more.$"
matches1= re.findall(pattern1, text)

for i in matches1:
  print("Match1:", i)


pattern2= r"\$*7"
matches2= re.findall(pattern2, text)

for i in matches2:
  print("Match2:", i)
# Out:
# Match1: more.
# Match2: $7

# %%
# 19. 정규표현식에서 백슬래시(\)는 이스케이프 문자로 사용되며, 특수문자를 나타내거나 메타 문자 자체를 일반 문자로 인식하도록 함.
# 백슬래시를 사용하여 특수문자를 매칭할 수 있다. 예를 들어, \는 실제 점 문자(.)를 매치

import re

text= "Hello, world.\n This is test #5."
pattern= r"\."

matches= re.findall(pattern, text)

for i in matches:
  print("Match:", i)
# Out:
# Match: .
# Match: .

# %%
# 19.a
import re

text= "Hello, world.\n This is test #5."
pattern= r"."

matches= re.findall(pattern, text)

for i in matches:
  print("Match:", i)
# Out:
# Match: H
# Match: e
# Match: l
# Match: l
# Match: o
# Match: ,
# Match:
# Match: w
# Match: o
# Match: r
# Match: l
# Match: d
# Match: .
# Match:
# Match: T
# Match: h
# Match: i
# Match: s
# Match:
# Match: i
# Match: s
# Match:
# Match: t
# Match: e
# Match: s
# Match: t
# Match:
# Match: #
# Match: 5
# Match: .

# %%
# 20. 정규표현식에서 백슬래시(\)는 이스케이프 문자로 사용되며, 특수문자를 나타내거나 메타문자 자체를 일반 문자로 인식하도록 함.
# 백슬래시를 사용하여 특수문자를 매칭할 수 있다. \$은 실제 dollar sign($)을 매치

import re

text= "The price is $100."
pattern= r"\$"

matches= re.findall(pattern, text)

for i in matches:
  print("Match:", i)
# Out:
# Match: $

# %%
import re

text= "The price is $100."
pattern= r"$"

matches= re.findall(pattern, text)

for i in matches:
  print("Match:", i)
# Out:
# Match:

# %%
# 21

import re

text= "The price is $100."
pattern= r"\d"  # 각각의 숫자에 일치

matches= re.findall(pattern, text)

for i in matches:
  print("Match:", i)
# Out:
# Match: 1
# Match: 0
# Match: 0

# %%
# 21a

import re

text= "The price is $100."
pattern= r"\d+"  # 각각의 숫자가 연속해서 일치하도록 패턴 지정

matches= re.findall(pattern, text)

for i in matches:
  print("Match:", i)
# Out:
# Match: 100

# %%
# 21b

import re

text= "The price is $100."
pattern= r"\D"  #숫자가 아닌 문자, 기호에 일치

matches= re.findall(pattern, text)

for i in matches:
  print("Match:", i)
# Out:
# Match: T
# Match: h
# Match: e
# Match:
# Match: p
# Match: r
# Match: i
# Match: c
# Match: e
# Match:
# Match: i
# Match: s
# Match:
# Match: $
# Match: .

# %%
# 21c
# 만약 100이라는 문자열 전체에 대한 하나의일치를 원한다면 r"\d+"와 같이 + 메타문자

import re

text1= "The price is $100 and the number pi is approximately 3.14."
pattern1= r"\d+"

text2= "The number pii is approximately 3.14592653358979323846 and you will hear a lot about it in Math class from 1st Grade to the"
pattern2=  r"\d+\.\d+"  # 메타문자(+)를 사용하여 숫자가 하나 이상 연속해서 일치하도록 패턴 지정

matches1= re.findall(pattern1, text1)
matches2= re.findall(pattern2, text2)

print(matches1)  # 새로운 추가 as of 4/30/24
for i in matches1:
  print("Match1:", i)

  print('\n')  # 새로 추가 as of 4/30/24

  for i in matches2:
    print("Match2:", i)
# Out:
# ['100', '3', '14']
# Match1: 100
#
#
# Match2: 3.14592653358979323846
# Match1: 3
#
#
# Match2: 3.14592653358979323846
# Match1: 14
#
#
# Match2: 3.14592653358979323846

# %%
# 22

import re

text= "The price is $100."
pattern= r"\D"  # 숫자가 아닌 문자(기호 포함)에 일치

matches= re.findall(pattern, text)

for i in matches:
  print("Match:", i)
# Out:
# Match: T
# Match: h
# Match: e
# Match:
# Match: p
# Match: r
# Match: i
# Match: c
# Match: e
# Match:
# Match: i
# Match: s
# Match:
# Match: $
# Match: .

# %%
# 23  \s: white space를 말함.

import re

text= "Hello    World"
pattern= r"\s"  # 공백문자에 일치

matches= re.findall(pattern, text)

for match in matches:
  print("Match:", match)
# Out:
# Match:
# Match:
# Match:
# Match:

# %%
# 23a  \s: white space를 말함.

import re

text= "Hello    World"
pattern= r"\s"  # 공백문자에 일치

matches= re.findall(pattern, text)
print("Match:", matches)

for match in matches:
  print("Match:", match)
# Out:
# Match: [' ', ' ', ' ', ' ']
# Match:
# Match:
# Match:
# Match:

# %%
# 24

import re

text= "Python is _awesome_!"
pattern= r"\w"

matches= re.findall(pattern, text)

for match in matches:
  print("Match:", match)
# Out:
# Match: P
# Match: y
# Match: t
# Match: h
# Match: o
# Match: n
# Match: i
# Match: s
# Match: _
# Match: a
# Match: w
# Match: e
# Match: s
# Match: o
# Match: m
# Match: e
# Match: _

# %%
import re

text= "Python is _awesome_!!!!!!!!!!!!!!!!!!!"
pattern= r"\w"

matches= re.findall(pattern, text)

for match in matches:
  print("Match:", match)
# Out:
# Match: P
# Match: y
# Match: t
# Match: h
# Match: o
# Match: n
# Match: i
# Match: s
# Match: _
# Match: a
# Match: w
# Match: e
# Match: s
# Match: o
# Match: m
# Match: e
# Match: _

# %%
# 26

import re

text= "Python 007 is awesome!"
pattern= r"\w+"  # 알파벳, 숫자가 한개 이상

matches= re.findall(pattern, text)

for match in matches:
  print("Match:", match)
# Out:
# Match: Python
# Match: 007
# Match: is
# Match: awesome

# %%
# 26

import re

text= "Python a007 is awesome!"
pattern= r"\w+"  # 알파벳, 숫자가 한개 이상

matches= re.findall(pattern, text)

for match in matches:
  print("Match:", match)
# Out:
# Match: Python
# Match: a007
# Match: is
# Match: awesome

# %%
# 27

import re
text= '123 Main Street Street and 5 Avenue'
pattern= r"\d+\s\w+"  # 숫자, 공백, 단어 매치

matches= re.findall(pattern, text)
print(matches)

for i in matches:
  print("Match:", i)
# Out:
# ['123 Main', '5 Avenue']
# Match: 123 Main
# Match: 5 Avenue

# %%
# 27.a

import re
text1= '123 Main Street Street and 5th Avenue'
pattern= r"\d+t?h?\s\w+"  # 숫자 후 t,h 상관 X, 공백, 단어 매치

matches= re.findall(pattern, text1)
print(matches)
# Out:
# ['123 Main', '5th Avenue']
