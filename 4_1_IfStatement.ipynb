# %%
x= 100
y= 95

if x > y:
  print('x is greater than y.')


else:
  print('x is smaller than or equal to y.')  # x가 y보다 작거나 같을 경우 출력
# Out:
# x is greater than y.

# %%
x= 0
y= 0

if x > y:
  print('x is greater than y')

else:
  print('x is smaller than or equal to y')
# Out:
# x is smaller than or equal to y

# %%
x= 345
y= 678

if x > y:
  print('x is greater than y.')


else:
  print('x is smaller than or equal to y.')
# Out:
# x is smaller than or equal to y.

# %%
listdata = ['a', 'b', 'c']
if 'a' in listdata:
  print ('a가 listdata 안에 있습니다.')
  print(listdata)
# Out:
# a가 listdata 안에 있습니다.
# ['a', 'b', 'c']
